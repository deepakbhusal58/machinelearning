# %% [markdown]
# import all the libraries needed for the analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# dataset is loaded into the data variable
data = pd.read_csv('D:\datasets\housing.csv')
data.head(100)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# ..        ...       ...                 ...          ...             ...
# 95    -122.26     37.80                36.0       5329.0          2477.0
# 96    -122.26     37.82                31.0       4596.0          1331.0
# 97    -122.26     37.81                29.0        335.0           107.0
# 98    -122.26     37.82                22.0       3682.0          1270.0
# 99    -122.26     37.82                37.0       3633.0          1085.0
#
#     population  households  median_income  median_house_value ocean_proximity
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# all the rows with null values are removed
data.dropna(inplace=True)

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ocean_proximity's label is divided into 5 features in a dataset

# %%
# the 5 features of ocean_proximity is concatenate with the dataset b removing ocean_proximity itself
train_data=data.join(pd.get_dummies(data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# train_test_split is imported to divide the dataset for training and spliting data

from sklearn.model_selection import train_test_split

X = train_data.drop(['median_house_value'], axis=1)
y = train_data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3339     -122.59     38.78                15.0        764.0           145.0
# 14754    -117.05     32.56                17.0        985.0           233.0
# 5704     -118.26     34.23                38.0       1107.0           194.0
# 14527    -117.14     32.92                 7.0       1308.0           418.0
# 1715     -122.31     38.00                29.0       3108.0           534.0
# ...          ...       ...                 ...          ...             ...
# 879      -122.01     37.56                24.0       2563.0           485.0
# 3580     -118.53     34.23                27.0       2131.0           543.0
# 10817    -117.95     33.63                17.0       6745.0          1547.0
# 2943     -118.97     35.36                31.0       1418.0           306.0
# 8099     -118.22     33.81                41.0        726.0           166.0
#
# ...

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20278    -119.20     34.19                19.0       9503.0          1769.0
# 3608     -118.46     34.23                16.0       6338.0          1768.0
# 12862    -121.39     38.69                30.0       2897.0           506.0
# 16603    -120.69     35.62                35.0       3451.0           713.0
# 5518     -118.39     33.97                44.0       1097.0           186.0
# ...          ...       ...                 ...          ...             ...
# 8862     -118.39     34.06                52.0       1213.0           194.0
# 885      -121.97     37.55                17.0       4924.0          1247.0
# 16694    -120.65     35.12                19.0       2949.0           662.0
# 11115    -117.87     33.84                23.0       1678.0           369.0
# 16735    -122.40     37.68                41.0       2267.0           486.0
#
# ...

# %%
y_train
# Out:
# 3339     103100.0
# 14754    134500.0
# 5704     263700.0
# 14527    106300.0
# 1715     170800.0
#            ...
# 879      216100.0
# 3580     230400.0
# 10817    271600.0
# 2943      46700.0
# 8099     156900.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
y_test
# Out:
# 20278    218500.0
# 3608     154600.0
# 12862     88400.0
# 16603    161700.0
# 5518     361400.0
#            ...
# 8862     500001.0
# 885      189400.0
# 16694    178100.0
# 11115    237300.0
# 16735    272200.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
# the model is trained 
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20278    -119.20     34.19                19.0       9503.0          1769.0
# 3608     -118.46     34.23                16.0       6338.0          1768.0
# 12862    -121.39     38.69                30.0       2897.0           506.0
# 16603    -120.69     35.62                35.0       3451.0           713.0
# 5518     -118.39     33.97                44.0       1097.0           186.0
# ...          ...       ...                 ...          ...             ...
# 8862     -118.39     34.06                52.0       1213.0           194.0
# 885      -121.97     37.55                17.0       4924.0          1247.0
# 16694    -120.65     35.12                19.0       2949.0           662.0
# 11115    -117.87     33.84                23.0       1678.0           369.0
# 16735    -122.40     37.68                41.0       2267.0           486.0
#
# ...

# %%
reg.score(X_test, y_test)
print("Linear regression Model", reg.score(X_test, y_test))
# Out:
# Linear regression Model 0.64163616062199

# %%
reg.predict([[-122.40,37.68,41.0,2267.0,486.0,1045.0,459.0,4.1146,0,0,0,1,0]])
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([271291.61896051])

# %%
y_test.loc[16735]
# y_test
# Out:
# 272200.0

# %% [markdown]
# our predicted value for given input is 271292 with is approximately close to 272200(y_test)
